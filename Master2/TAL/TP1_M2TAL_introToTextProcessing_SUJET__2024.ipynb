# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1L9JLLQHPZoMRwzYfmKcyM9VME_SHeZrr)

# %% [markdown]
# # TP 1 : pre-processing texts
#
# In this practical session, we will see a few basic processing of textual data.
#
# Within a computer, text is encoded as a string of characters.
# In order to analyze textual data within NLP applications, we first need to properly preprocess it.
# An NLP preprocessing pipeline generally consists of the following steps :
# * sentence segmentation
# * tokenisation
# * normalization: lower-casing, lemmatization, optionally removing stop-words and punctuation
# * pos-tagging
# * named entity recognition
# * parsing
#
# The first two steps are necessary, while the others are optional.
#
# For these exercises, we will mainly use the module **spacy** (already installed on google colab, but some additional libraries might be missing).
#
# Spacy provides ways to carry out tasks such as segmentation, tokenization, lemmatization and pos-tagging.
#
#
# We will also extract information from Wikipedia pages as an example.

# %% [markdown]
# ## 0- Upload and read the text files
#
# At first, we're going to use a text written in English. Then, we'll try to apply the tools to French.
# We'll use the wikipedia library to extract pages from wikipedia

# %%
! pip install wikipedia
# Out:
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia) (2.6)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11679 sha256=77134c60d82db71fcc2e7af620c34483715833a50285d93e2075b85e8011f3e4
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
import wikipedia
wikipedia.set_lang('en')
text_en = wikipedia.page("AdaLovelace")
print(text_en.content[:1000])
# Out:
# Augusta Ada King, Countess of Lovelace (née Byron; 10 December 1815 – 27 November 1852), also known as Ada Lovelace, was an English mathematician and writer chiefly known for her work on Charles Babbage's proposed mechanical general-purpose computer, the Analytical Engine. She was the first to recognise that the machine had applications beyond pure calculation.
# Lovelace was the only legitimate child of poet Lord Byron and reformer Anne Isabella Milbanke. All her half-siblings, Lord Byron's other children, were born out of wedlock to other women. Lord Byron separated from his wife a month after Ada was born and left England forever. He died in Greece when she was eight. Lady Byron was anxious about her daughter's upbringing and promoted Lovelace's interest in mathematics and logic in an effort to prevent her from developing her father's perceived insanity. Despite this, Lovelace remained interested in her father, naming her two sons Byron and Gordon. Upon her death, she was buried next

# %%
wikipedia.set_lang('fr')
text_fr = wikipedia.page("Lovelace")
print(text_fr.content[:1000])
# Out:
# Ada Lovelace, de son nom complet Augusta Ada King, comtesse de Lovelace, née Ada Byron le 10 décembre 1815 à Londres et morte le 27 novembre 1852 à Marylebone dans la même ville, est une pionnière de la science informatique.
# Elle est principalement connue pour avoir réalisé le premier véritable programme informatique, lors de son travail sur un ancêtre de l'ordinateur : la machine analytique de Charles Babbage. Dans ses notes, on trouve en effet le premier programme publié, destiné à être exécuté par une machine, ce qui fait d'Ada Lovelace la première personne à avoir programmé au monde. Elle a également entrevu et décrit certaines possibilités offertes par les calculateurs universels, allant bien au-delà du calcul numérique et de ce qu'imaginaient Babbage et ses contemporains.
#
#
# == Biographie ==
#
#
# === Environnement familial ===
#
# Ada était la seule fille légitime du poète George Gordon Byron et de son épouse Annabella Milbanke, une femme intelligente et cultivée, cousine de Caroline La

# %% [markdown]
# ## 1- Using Spacy
#
# All info about Spacy: https://spacy.io/ ; More info on the pipelines: https://spacy.io/usage/processing-pipelines
#
# Spacy is a more realistic library for NLP than NLTK, with higher performances on the basic processing steps.
#
# Spacy can be used to directly tokenize any text.
# With spacy, we build a pipeline that does everything at once.
# To make it work, you need to load a model specific to the target language, for example 'en' for English (there are also some domain specific models).
#
#
# The model corresponds to a processing 'pipeline':
#   by default, it includes the tokenisation, the lemmatization and the POS tagging
#
# Using spacy:
# - import the spacy module into Python
# - load all the necessary models, e.g. for English

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Then process a text with the pipeline:

# %%
doc = nlp(text_en.content)

# %% [markdown]
# Try to see what is stored with the document, especially doc.vocab, doc.sent and see what you get when you iterate over a document or its parts.
#
# Hint: You can either access Spacy's manual on the internet to find out how to access the information, or look at the built-in help by typing help(doc). https://spacy.io/api/doc

# %%
len(doc.vocab)
v = [w.text for w in doc.vocab]
print(v[:10])
# Out:
# ['Moque-t-on', 'ü.', 'Turing', 'symbole', 'Perfection', 'commencé', 'illustré', 'Cette', 'c.', 'qui']

# %%
for w in doc.sents:
  print(w[:2])
# Out:
# Ada Lovelace
# Ada King
# , est
# Elle est
# Dans ses
# Elle a
# ==
# ==
# =
# Environnement familial
# Ada
# était la
#
#
# Byron recherchait
# nécessaire].
# Lady
# Melbourne (
# lui suggère
# Cette union
# Ada naît
# Le premier
# Le prénom
# Le 21
# Il ne
# Annabella adorait
# Byron l’
# Annabella fit
# En 1832
# Le 5
# Ils deviennent
# Parmi ses
# Elle se
# Ils auront
# William était
# La famille
# Son titre
# Elle est
# La santé
# À cette
# Les études
# Ada prend
# Le 6
# Je crois
# Elle mentionne
# énergie inépuisable
# En 1841
# Elle tourne
# ==
# = Mémoire
# sur la
# =
#
#
# En octobre
# Charles Wheatstone
# Elle passe
# Babbage lui-même
# n'intervient
# Il demande
# Babbage propose
# Elle ajoute
# La note
# Le programme
# De plus
# On ne
# dans quelle
# Ce qui
# Selon Betty
# En revanche
# Cela ne
# Babbage,
# Analytical Engine
# , tous
# Ada Lovelace
# Dans d'
# Babbage avait
# Mais il
# En revanche
# Ada Lovelace
# Un autre
# Ceci est
# La Machine
# en fait
# »
#
#
# ==
# = Ruine
# Dans l’
# Elle travailla
# Elle mourut
# Elle laissait
# Cette dernière
# Elle fut
# Notoriété posthume
# Et c'
# L'idée
# Ada est
# nécessaire].
#
# Ada
# Lovelace est
# On peut
# L'entreprise
# L'astéroïde
# Adalovelace porte
# L'École
# Ada
# Lovelace la
# L'Ada
# Lovelace Day
# Ada est
# Le film
# Ada (
# (
# 1997)
# , réalisé
# Hershman Leeson
# , établit
# Ada
# , une
# Ada Enigma
# Dutreuil et
# le personnage
# Le nom
# ADA est
# Zone of
# Lady
# Ada Lovelace
# Falkenstein de
# Lovelace (
# Ada Lovelace
# Ada Gordon
# , apparaît
# Elle accompagne
# Ada
# , présentée
# Arena 13
# .
#
# Dess est
# Son personnage
# Elle est
# Elle fait
# Les Oubliés
# Une clone
# Ada,
# Ada &
# ==
# Annexes =
# =
#
#
#
# ==
# = Bibliographie
# Benjamin Woolley
# s Daughter
# A Life
# , The
# du Sorbier
# , 31
# de Ada
# Ada,
# La fille
# ISBN 978
# Émissions =
# (fr
# Cherchez la
# Ada Lovelace
# - L'
# Ada Lovelace
# page consultée
# =
# Articles connexes
# ==
# Histoire de
# Ada (
# Ada Initiative
# Liste des
# Prix Lovelace
# Ada
# Lovelace Day
# =
# = Liens
# Prénom de
# ADA »
# Ada Lovelace
# , La
# Sketch of
# Invented by
# Babbage
# , Esq
# avec des
# 3 (
# British Museum
# National
# Portrait Gallery
# Ressource relative
# The Encyclopedia

# %% [markdown]
# ### 1.1 Tokenisation
#
# **Exercise 1:** Tokenize the text in French
# * Find a model for French and tokenize the text in the file. Hint: you will need to download the model first, that can be done in the notebook using: *spacy.cli.download( model_name )*
# * What does contain the *doc* variable? Hint: You can either access Spacy's manual on the internet to find out how to access the information, or look at the built-in help by typing help(doc). https://spacy.io/api/doc
# * Print the individual tokens. Do you see any error?
# * How many tokens do we have?
# * How many words / types / unique tokens do we have (i.e. vocabulary size)?
# * Use Pandas to better visualize the results

# %%
import spacy.cli
spacy.cli.download("fr_core_news_sm")
spacy.cli.download("fr_core_news_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
import numpy as np

# Load the model
nlp=spacy.load('fr_core_news_lg')

# Process the text
doc = nlp(text_fr.content)



print('Preprocessing done')
tokens = [w.text for w in doc]
print(tokens[:30])
# in our doc variable, and we can access its different annotations by looping through it
# Out:
# Preprocessing done
# ['Ada', 'Lovelace', ',', 'de', 'son', 'nom', 'complet', 'Augusta', 'Ada', 'King', ',', 'comtesse', 'de', 'Lovelace', ',', 'née', 'Ada', 'Byron', 'le', '10', 'décembre', '1815', 'à', 'Londres', 'et', 'morte', 'le', '27', 'novembre', '1852']

# %% [markdown]
# Do you see some ssues with tokenisation?

# %% [markdown]
# **il y'a des mots en anglais ?**

# %% [markdown]
# #### Getting some help
#
# Hint: You can either access Spacy's manual on the internet to find out how to access the information, or look at the built-in help by typing *help(doc)*.
#
# https://spacy.io/api/doc

# %% [markdown]
# #### Pandas
#
# You can use Pandas to better visualize the results

# %%
# Using pandas for a better visualization
import pandas as pd

spacy_tokens = [w.text for w in doc]
data = pd.DataFrame(spacy_tokens,
             columns=['Word'])

# %%
data["Word"].value_counts().sort_values(ascending=False)
# Out:
# Word
# ,            213
# de           145
# .            108
# Ada           79
# et            71
#             ...
# Toute          1
# 59             1
# Articles       1
# connexes       1
# féminisme      1
# Name: count, Length: 1177, dtype: int64

# %% [markdown]
# ### 1.2 Sentence segmentation
#
# **Exercise 5:**
# Apart from token segmentation, Spacy has also automatically segmented our document intro sentences.
# * **(a)** Print out the different sentences of the document.
# Hint: Look at the "Data descriptors " in the help page for 'doc'.

# %%
for sent in doc.sents:
  print(sent[:10])
# Out:
# Ada Lovelace, de son nom complet Augusta Ada King
# Elle est principalement connue pour avoir réalisé le premier véritable
# Dans ses notes, on trouve en effet le premier
# Elle a également entrevu et décrit certaines possibilités offertes par
# nécessaire]. Lady Melbourne (en) lui suggère sa propre
# Cette union est ensuite encouragée par Augusta Leigh, la
# Ada naît en décembre de cette même année.
# Le premier prénom d'Ada, Augusta, aurait été
# Le prénom Ada aurait été choisi par Byron lui-même,
# Le 21 avril, Byron signe l'acte de séparation
# Il ne les revit jamais.
# Annabella adorait les
# Byron l’appelait même parfois « la princesse des parallélogrammes
# Annabella fit en sorte que les tuteurs d'Ada lui
# En 1832, Ada rencontre Mary Somerville, éminente chercheuse
# Le 5 juin 1833, Mary lui présente Charles Babbage
# Ils deviennent très proches, Ada semblant trouver en Babbage
# Parmi ses autres connaissances, on compte David Brewster,
# Elle se marie en 1835 avec William King, 1er
# Ils auront trois enfants : Byron, né le 12
# William était dévoué à Ada et encourageait les goûts et
# La famille vécut à Ockham Park, à Ockham.
# Son titre et son nom complet furent pendant la plus
# La très honorable Augusta Ada, comtesse de Lovelace.
# Elle est plus connue sous le nom de Ada Lovelace
# À cette date, elle éprouve le besoin de reprendre
# Les études d'Ada reprennent, et De Morgan trouve
# Ada prend confiance dans ses capacités en mathématiques, encouragée
# Le 6 février 1841, Ada écrit à sa mère
# Je crois que je possède une singulière combinaison de qualités
# Elle mentionne son « énergie inépuisable et insatiable » et
# En 1841, Ada a de nouveau des problèmes de
# Elle tourne dès lors entièrement son travail vers la machine
# Charles Wheatstone propose à Ada Lovelace, qui a un
# Elle passe neuf mois, entre 1842 et 1843,
# Babbage lui-même n'intervient que très peu, étant malade
# Il demande alors à Ada pourquoi elle n'avait pas
# Babbage propose alors à Ada d'augmenter la traduction avec
# Elle ajoute à cet article sept notes, labellisées de
# La note G s'appuie sur un véritable algorithme très
# Le programme qui en résulte est souvent considéré comme le
# De plus, ce programme comporte selon Catherine Dufour la
# On ne sait pas exactement dans quelle mesure Ada Lovelace
# Ce qui semble sûr c'est qu'Ada a eu
# Selon Betty Toole, Ada était tout à fait en
# En revanche, Bruce Collier, un des meilleurs spécialistes
# Cela ne serait qu'une légère exagération de dire que
# Selon Stephen Wolfram, on n'a jamais retrouvé,
# Babbage, à la fin de sa vie, avait
# Ada Lovelace ayant conçu son programme en 1842, ces
# Dans d'autres notes, Ada Lovelace montre une perception
# Babbage avait une vision de sa machine comme étant tournée
# Mais il n'a rien publié allant dans ce sens
# En revanche, Ada Lovelace décrit explicitement des possibilités allant
# Un autre passage des notes d'Ada, cité par
# Ceci est une erreur.
# La Machine peut arranger et combiner les quantités numériques exactement
# en fait elle peut donner des résultats en notation algébrique
# »
#
#
# Il fallut attendre les années 1930 avec Alan Turing pour
# Elle travailla à un système qui devait lui permettre de
# Elle mourut à l'âge de 36 ans d'un
# Elle laissait deux fils et une fille.
# Cette dernière, Anne Blunt, est connue pour avoir
# Elle fut enterrée conformément à son souhait près de son
# Et c'est en son hommage qu'on a appelé
# L'idée de choisir le nom Ada est attribuée à
# nécessaire].
# Ada Lovelace est considérée par les historiens de
# On peut voir notamment son portrait sur les hologrammes d'
# L'entreprise Nvidia a également décidé de nommer sa nouvelle
# L'astéroïde (232923)
# Adalovelace porte son nom.
#
# La cryptomonnaie Cardano porte également son nom en hommage,
# L'École polytechnique fédérale de Lausanne baptise place
# Ada Lovelace
# la place de l'entrée nord
# .
#
# L'Ada Lovelace Day est un événement annuel organisé le
# Le film Conceiving
# Ada (
# en) (1997), réalisé par Lynn Hershman
# , établit un parallèle entre l'existence d'une Britannique
# Ada, une petite fille douée en mathématiques, personnage
# Le nom d'Ada Byron a été choisi par la
# Lady
# Ada Lovelace est un personnage expert en machine de calcul
# L'Espace d'un an, de Becky Chambers.
# Ada Lovelace, d'abord présentée sous son nom de
# Gordon (car l'action la concernant se déroule en
# , apparaît dans l'épisode 2 de la saison 12
# Elle accompagne le Docteur à travers diverses époques (la
# Ada, présentée comme programmeuse, est l'un des
# Ada Lovelace est l’idole du personnage Dess de Scott
# Dess est polymathe.
#
# Son personnage apparaît dans le 2e épisode de la saison
# Elle est interprété par Emerald Fennell.
#
# Elle fait l'objet d'un portrait dans la bande
# Les Oubliés de la science de Camille Van Belle (
# Une clone d'Ada Lovelace est présente dans le jeu
# Ada
# , l'héroïne du conte moderne
# Ada & Zangemann   de Matthias Kirscher, illustré par
# , The MIT Press, 1985 (ISBN 0-
# Perfection
# , Oxford University Press, 1998 :
#
# (en
# , Ada de Lovelace et la programmation informatique,
# éd.
# du Sorbier, Paris, 1998, 31 p.
# de Ada Byron, a life and a legacy,
# ), 1998, 323 p.  (ISBN 0
# La pionnière de l'informatique, Librairie Arthème Fayard,
# p. (ISBN 2-213-71279-4
# La fille de Byron lance le premier programme informatique,
# Ada Lovelace, la visionnaire, À pas de loups
# Ada Lovelace
# - L'invention de l'ordinateur sur Arte (page
# Toute une vie (2023), France Culture,
# Articles connexes ===
# Histoire de l'informatique
# Ada
# Initiative
# Famille Byron
# Liste des premières femmes par
# Prix Lovelace
# -Babbage de l'Académie des sciences et la Société
# Ada Lovelace Day
#
#
# ===
# Liens externes ===
# « Prénom de code
#
# «
# Ada Lovelace, la grande ordinatrice »
# , La Méthode scientifique, France Culture, 26 septembre
# Invented by
# Charles Babbage, Esq.
# avec des notes de la traductrice Ada Augusta, comtesse
# 3 (1842)
#
#
# === Bases de
# Portrait Gallery
#
# Ressource relative à la littérature : The Encyclopedia of Science
# Comic Vine
#
#
# Portail des mathématiques
# Portail des femmes et du féminisme
# Portail du XIXe siècle
# Portail de la programmation informatique
# Portail du Royaume-Uni   Portail de l’histoire

# %% [markdown]
# ## 3- POS tagging
#
# Remember that the model corresponds to a processing 'pipeline' in Spacy:
#   - by default, it includes the tokenisation, the lemmatization and the POS tagging
#
# **Exercise**
# - print each individual token, together with its lemmatized form and part of speech tag
# - Use Panda to better visualize the results
# - Look at the results, do you see any error?
# - You can use the method 'spacy.explain' to have information about some annotation, for example the POS tags. Apply it to each POS tag to get a more detailed label.

# %%
tokens = [w.text for w in doc]
len(tokens)
# Out:
# 3556

# %%
tokens = [w for w in doc]
for token in tokens [:10]:
  print(token ,  token.lemma_, token.pos_, token.tag)
# Out:
# Ada Ada PROPN 96
# Lovelace Lovelace PROPN 96
# , , PUNCT 97
# de de ADP 85
# son son DET 90
# nom nom NOUN 92
# complet complet ADJ 84
# Augusta Augusta PROPN 96
# Ada Ada PROPN 96
# King King PROPN 96

# %% [markdown]
# #### Pandas
#
# You can use Pandas to better visualize the results

# %%
# Using pandas for a better visualization
import pandas as pd

spacy_pos_tagged = [(w, w.lemma_, w.tag_, w.pos_) for w in doc]
pd.DataFrame(spacy_pos_tagged,
             columns=['Word', 'Lemma', 'POS tag', 'Tag type'])
# Out:
#           Word     Lemma POS tag Tag type
# 0          Ada       Ada   PROPN    PROPN
# 1     Lovelace  Lovelace   PROPN    PROPN
# 2            ,         ,   PUNCT    PUNCT
# 3           de        de     ADP      ADP
# 4          son       son     DET      DET
# ...        ...       ...     ...      ...
# 3551        de        de     ADP      ADP
# 3552        l’        l’     DET      DET
# 3553  histoire  histoire    NOUN     NOUN
# 3554       des        de     ADP      ADP
# 3555  sciences   science    NOUN     NOUN
#
# [3556 rows x 4 columns]

# %% [markdown]
# #### Look at the results: do you see any issues?

# %% [markdown]
# #### Notes on POS tags:
#
# * You can use the method 'explain' to have information about some annotation, for example the POS tags, see the code below.
# * Here we used a very small set of POS (vs e.g. 36 in the PTB: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html)

# %%
# Inspect POS tags
all_tags = set()
for token in doc:
  all_tags.add(token.pos_)
for tag in all_tags:
  print( tag, spacy.explain(tag)) # explain each label
# Out:
# X other
# SPACE space
# NOUN noun
# PROPN proper noun
# PRON pronoun
# ADV adverb
# CCONJ coordinating conjunction
# SYM symbol
# SCONJ subordinating conjunction
# ADJ adjective
# VERB verb
# PUNCT punctuation
# NUM numeral
# DET determiner
# AUX auxiliary
# ADP adposition

# %% [markdown]
# ## 5- Named entity recognition
#
# As part of the preprocessing pipeline, Spacy has also carried out named entity recognition.
#
# **Exercise 8:**
# * print out each named entity, together with the label assigned to it
# * what do the labels stand for?
# * Use the module called 'displacy' to visualize the Named Entities directly in the text.

# %%
for w in doc.ents:
  print(w.text, w.label_)
# Out:
# Ada Lovelace PER
# Augusta Ada King MISC
# comtesse de Lovelace PER
# Ada Byron PER
# Londres LOC
# Marylebone LOC
# Charles Babbage PER
# Ada Lovelace PER
# Babbage PER
# Environnement LOC
# Ada PER
# George Gordon Byron PER
# Annabella Milbanke PER
# Caroline Lamb PER
# Byron PER
# Byron PER
# Lady Melbourne PER
# miss Milbanke PER
# Augusta Leigh PER
# Byron PER
# Byron PER
# Annabella PER
# Ada PER
# Ada MISC
# Augusta LOC
# Augusta PER
# Byron PER
# Ada MISC
# Byron PER
# Byron PER
# Annabella PER
# Byron PER
# Ada MISC
# Byron PER
# acte de séparation MISC
# Royaume-Uni LOC
# Annabella PER
# Byron PER
# Annabella PER
# Ada MISC
# Ada PER
# Mary Somerville PER
# Mary PER
# Charles Babbage PER
# Ada MISC
# Ada MISC
# Babbage PER
# David Brewster PER
# Charles Wheatstone PER
# Charles Dickens PER
# Michael Faraday PER
# William King PER
# comte de PER
# Byron PER
# Annabella PER
# Anne Blunt PER
# Ralph Gordon PER
# William PER
# Ada MISC
# Ada MISC
# Ockham Park LOC
# Ockham PER
# La très honorable MISC
# Augusta Ada PER
# comtesse de Lovelace PER
# Ada Lovelace PER
# Lady Lovelace PER
# Ada MISC
# Babbage PER
# Auguste De Morgan PER
# Ada MISC
# De Morgan PER
# Ada MISC
# Ada MISC
# De Morgan PER
# Ada PER
# Nature MISC
# Ada PER
# Babbage PER
# Mémoire sur la machine MISC
# Babbage PER
# Babbage PER
# Louis-Frédéric Ménabréa PER
# Charles Wheatstone PER
# Ada Lovelace PER
# Scientific Memoirs MISC
# Babbage PER
# Ada MISC
# Babbage PER
# Ada MISC
# Ada PER
# Charles Babbage PER
# Ada PER
# A LOC
# G LOC
# G MISC
# Bernoulli PER
# Catherine Dufour PER
# Babbage PER
# Jacquard PER
# Ada Lovelace PER
# Babbage PER
# Ada MISC
# Bernoulli PER
# Babbage PER
# Ada MISC
# Betty Toole PER
# Ada MISC
# Babbage PER
# Ada MISC
# Babbage PER
# Bruce Collier PER
# Babbage PER
# Babbage PER
# Ada Lovelace PER
# Stephen Wolfram PER
# Babbage PER
# Bernoulli PER
# Babbage PER
# Notations of the Analytical Engine MISC
# Babbage PER
# Ada Lovelace PER
# Babbage PER
# Ada Lovelace PER
# Doron Swade PER
# Babbage PER
# Ada Lovelace PER
# Ada MISC
# Doron Swade PER
# La Machine MISC
# Alan Turing PER
# Ruine et mort MISC
# Babbage PER
# Lady Lovelace PER
# paris LOC
# Epsom LOC
# Anne Blunt PER
# Moyen-Orient LOC
# église Sainte-Marie-Magdalene de Hucknall LOC
# Newstead Abbey ORG
# comté de Nottingham LOC
# Tombée dans l'oubli MISC
# Ada Lovelace PER
# Ada MISC
# département de la Défense américain LOC
# DoD ORG
# CII Honeywell Bull ORG
# Français LOC
# Jean Ichbiah PER
# Ada MISC
# Jack Cooper PER
# Naval Material Command MISC
# Ada Lovelace PER
# Microsoft ORG
# Nvidia ORG
# Ada Lovelace PER
# RTX MISC
# (232923) LOC
# Adalovelace PER
# cryptomonnaie Cardano MISC
# Ada MISC
# Lovelace MISC
# École polytechnique fédérale de Lausanne ORG
# Ada Lovelace PER
# Ada MISC
# La Machine à différences MISC
# Bruce Sterling PER
# William Gibson PER
# Babbage PER
# Lynn Hershman Leeson PER
# Britannique LOC
# Ada Lovelace PER
# Tilda Swinton PER
# Ada MISC
# Nombre MISC
# Egger PER
# Thierry Smolderen PER
# Ada Lovelace PER
# Ada Enigma MISC
# Vincent Dutreuil PER
# François Maingoval PER
# Ada Lovelace PER
# machine Enigma MISC
# Ada Byron PER
# IRA ORG
# Institut régional d'administration ORG
# de Lille LOC
# ADA ORG
# Jehuty MISC
# Zone of the Enders MISC
# ADA ORG
# Ada Lovelace PER
# Castle Falkenstein MISC
# Mike Pondsmith PER
# Lovelace LOC
# Lovey PER
# L'Espace d'un an MISC
# Becky Chambers PER
# Ada Lovelace PER
# Ada MISC
# Doctor Who PER
# La Chute des espions MISC
# Docteur PER
# Maître PER
# Ada MISC
# Arena 13 MISC
# Joseph Delaney PER
# Ada Lovelace PER
# Dess de Scott Westerfeld PER
# Midnighters ORG
# Dess PER
# Victoria MISC
# Emerald Fennell MISC
# Les Oubliés de la science MISC
# Camille Van Belle PER
# Alisio Sciences MISC
# Ada Lovelace PER
# Starfield MISC
# Charybde 3 LOC
# Ada MISC
# Ada & Zangemann MISC
# Matthias Kirscher PER
# Sandra Brandstätter PER
# Creative Commons MISC
# Notes MISC
# Annexes LOC
# Benjamin Woolley PER
# The Bride of Science: Romance MISC
# Reason, and Byron's Daughter MISC
# McGraw-Hill MISC
# Dorothy Stein PER
# Ada: A Life and a Legacy MISC
# Cambridge LOC
# Mass MISC
# The MIT Press ORG
# ISBN ORG
# Doron Swade PER
# The Difference Engine MISC
# Charles Babbage PER
# Penguin ORG
# Non-Classics LOC
# Bruce Collier PER
# Charles Babbage PER
# Oxford University Press ORG
# Betty Toole PER
# Ada and the first computer MISC
# Scientific American ORG
# Stephen Wolfram PER
# Untangling the Tale of Ada Lovelace MISC
# blog.stephenwolfram.com ORG
# Jean-Paul Soyer PER
# Ada de Lovelace PER
# Sorbier LOC
# Paris LOC
# ISBN ORG
# Dorothy Stein PER
# Ada Byron PER
# Ada Byron PER
# Maurice Gabail PER
# Seghers MISC
# Paris LOC
# ISBN ORG
# Betty Alexandra Toole PER
# Ada MISC
# the enchantress of numbers MISC
# Strawberry Press ORG
# Mill Valley LOC
# Calif LOC
# ISBN ORG
# Catherine Dufour PER
# Ada MISC
# Librairie Arthème Fayard MISC
# ISBN ORG
# Jean-Luc Dousset PER
# Ada 1.0 PER
# Byron PER
# Jeanne d'Arc PER
# Anne Loyer PER
# Claire Gaudriot PER
# Ada Lovelace PER
# À pas de loups éditions MISC
# ISBN 978-2-93078-78-31 MISC
# Ada Lovelace PER
# Arte MISC
# Julie Gavras PER
# Arte ORG
# Ada Lovelace PER
# Radio France ORG
# France Culture ORG
# Toute une vie MISC
# France Culture ORG
# Articles MISC
# Histoire de l'informatique
#  MISC
# Ada MISC
# Ada MISC
# Famille Byron PER
# Prix Lovelace MISC
# Académie des sciences ORG
# Société informatique de France ORG
# Ada Lovelace Day PER
# Liens LOC
# ADA ORG
# La Conversation scientifique MISC
# France Culture ORG
# Ada Lovelace PER
# La Méthode scientifique MISC
# France Culture ORG
# Sketch of the Analytical Engine MISC
# Charles Babbage PER
# Esq PER
# Ada Augusta PER
# comtesse de Lovelace PER
# Scientific Memoirs MISC
# Bases de données et dictionnaires ===
#
# Ressources relatives aux beaux-arts MISC
# British Museum National LOC
# The Encyclopedia of Science Fiction
# Ressource relative MISC
# Comic Vine
#
#   MISC
# Portail LOC
# Portail du XIXe siècle    MISC
# Portail MISC
# Portail du Royaume-Uni   Portail de l’histoire des sciences LOC

# %%
# Explain the labels
for w in doc.ents[:10]:
  print(w.text, w.label_, spacy.explain(w.label_))
# Out:
# Ada Lovelace PER Named person or family.
# Augusta Ada King MISC Miscellaneous entities, e.g. events, nationalities, products or works of art
# comtesse de Lovelace PER Named person or family.
# Ada Byron PER Named person or family.
# Londres LOC Non-GPE locations, mountain ranges, bodies of water
# Marylebone LOC Non-GPE locations, mountain ranges, bodies of water
# Charles Babbage PER Named person or family.
# Ada Lovelace PER Named person or family.
# Babbage PER Named person or family.
# Environnement LOC Non-GPE locations, mountain ranges, bodies of water

# %%
from spacy import displacy

#try with dept instead of ent too.
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada Lovelace
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , de son nom complet
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Augusta Ada King
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     comtesse de Lovelace
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , née
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada Byron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  le 10 décembre 1815 à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Londres
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et morte le 27 novembre 1852 à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marylebone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  dans la même ville, est une pionnière de la science informatique.<br>Elle est principalement connue pour avoir réalisé le premier véritable programme informatique, lors de son travail sur un ancêtre de l'ordinateur : la machine analytique de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Charles Babbage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Dans ses notes, on trouve en effet le premier programme publié, destiné à être exécuté par une machine, ce qui fait d'
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada Lovelace
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  la première personne à avoir programmé au monde. Elle a également entrevu et décrit certaines possibilités offertes par les calculateurs universels, allant bien au-delà du calcul numérique et de ce qu'imaginaient
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Babbage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  et ses contemporains.<br><br><br>== Biographie ==<br><br><br>===
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Environnement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  familial ===<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  était la seule fille légitime du poète
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     George Gordon Byron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  et de son épouse
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Annabella Milbanke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , une femme intelligente et cultivée, cousine de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Caroline Lamb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , dont la liaison avec
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Byron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  fut à l'origine d'un scandale. <br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Byron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  recherchait une femme dont la fortune paierait ses dettes[réf. nécessaire].
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lady Melbourne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (en) lui suggère sa propre nièce,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     miss Milbanke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , mais celle-ci refuse dans un premier temps. Cette union est ensuite encouragée par
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Augusta Leigh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , la demi-sœur de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Byron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , et
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Byron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  épouse
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Annabella
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  en janvier 1815. <br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; l

# %% [markdown]
# Note on Named Entity Recognition: do you see any issues?

# %% [markdown]
# ## 6- Parsing
#
# Finally, as part of the pipeline, Spacy has also performed a dependency parsing (note that each module can de disabled if not needed).
#
# **Exercise 9:** Extract all Noun Phrases from the file
#
# * Retrieve the information from the dependency parses: dependent and head of each token
# * Use displacy to visualize a parse tree: first try with a simple sentence (e.g. *La petite brise la glace.*) then use the first sentence of the document.
# * Navigating the parse tree. Each element of the tree is associated to attributes: you can use them to inspect the different elements of the trees:
#   * Define a Panda dataframe with each token id associated to its head, with the relation between them. The eventual children of the current token are also printed.
# * Print all the adjectives and the noun they modify

# %%
sentences = [w.text for w in doc.sents]
print(sentences[0])
# Out:
# Ada Lovelace, de son nom complet Augusta

# %%
# Print for each token, its dependents and head
doc2 = "la petite fille brise la glace"
doc2 = nlp(doc2)
phrase = sentences[0]
displacy.render(doc2, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="9b970cf7430d45458b9dcec3727b8ede-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">petite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">fille</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">brise</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">glace</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b970cf7430d45458b9dcec3727b8ede-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b970cf7430d45458b9dcec3727b8ede-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b970cf7430d45458b9dcec3727b8ede-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b970cf7430d45458b9dcec3727b8ede-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b970cf7430d45458b9dcec3727b8ede-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b970cf7430d45458b9dcec3727b8ede-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b970cf7430d45458b9dcec3727b8ede-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b970cf7430d45458b9dcec3727b8ede-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b970cf7430d45458b9dcec3727b8ede-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b970cf7430d45458b9dcec3727b8ede-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# Visualization using displacy

# %% [markdown]
# #### Navigating the parse tree

# %%
# Navigating the parse tree

# %%
# Print the NOUNS modified by an ADJECTIVE

# %% [markdown]
# ## 7- Putting it all together
#
# Now we are going to use the skills practiced in the preceding exercises to build a simple question-answering system on a toy dataset (in French).
#
# We will focus on specific questions of the form "Qui a peint X ?".
# We will define patterns based on differents ways of formulating this question, and use them to extract the answer from a small toy corpus based on wikipedia pages on paintings.
#
# When you're done with this exercise, try to answer other types of questions, such as "Où est exposé X ?", "Quand a été peinte X ?".
#
# Below, we reload the spacy French model adding specific options to merge named entities containing multiple tokens.

# %%
# Load the model
nlp = spacy.load('fr_core_news_sm')

nlp.add_pipe("merge_entities")
nlp.add_pipe("merge_noun_chunks")

# %% [markdown]
# Here is the list of questions we will consider.
# You also need a corpus of source document, you can find it on Moodle (corpus_qa.txt).

# %%
question_list = [
    'La Joconde est un tableau de qui ?',
    'Le radeau de la méduse est une peinture réalisée par qui ?'
]
corpus = 'corpus_qa.txt'

# %% [markdown]
# **Exercise 10:** In this part, we focus on the first question. This question is designed to be similar to the document containing the answer. We can thus define a pattern based on its structure to extract the answer from the document.
#
# - Process the question using the spacy nlp pipeline
# - display its parse tree and / or print a Pandas dataframe containing information from the parse tree
# - Now to define a lexico-syntactic pattern, you are going to use spacy *DependencyMatcher* : https://spacy.io/usage/rule-based-matching#dependencymatcher
#   * Look at the doc to understand how it works
#   * Define a pattern that should match 'qui ' in the question

# %%
# Display the parse tree of the first question

# %%
from spacy.matcher import DependencyMatcher
# Define a lexico-syntactic pattern that allows to retrieve the answer

pattern_tableau = [

                   # ...

]

# If you match the pattern to the original question, it should output 'qui'

matcher = DependencyMatcher(nlp.vocab)
matcher.add("tableau", [pattern_tableau])

matches = matcher(q1_prep)

print(matches) # [(4851363122962674176, [6, 0, 10, 9])]
# Each token_id corresponds to one pattern dict
match_id, token_ids = matches[0]

for i in range(len(token_ids)):
  if pattern_tableau[i]["RIGHT_ID"] == 'mod':
    print(q1_prep[token_ids[i]].text)

# %% [markdown]
# **Exercise**:
# Retrieve the documents that are relevant to the question, i.e. the ones containing the keyword 'La Joconde'.
#
# It is recommended to define a function, that could be used for the next exercises. It could work by:
#
# * first indexing all the documents using the named entities present in the document (i.e. build a dictionnary mapping a named entity to all documents where it is present)
# * now the *retrieve_documents(...)* method should try to match the input keywork with a named entity and return the matching documents.
# * Test the function with 'Joconde':
#   * Does it work with the method based on named entities?
#   * Add a backup solution : if no document is found,simply try to find the string corresponding to the keyword in the document

# %%
# Retrieve the document that is relevant to the question, i.e. the one
# containing 'La Joconde'
# Indexation of the documents based on named entities
# + if no NE found, simple pattern matching


#

# %% [markdown]
# **Exercise 12:** Test the pattern
#
# - Apply the pattern to each sentence of the retrieved document, do you find the right answer?

# %%
#  Apply the pattern to each sentence of this document, do you find the right answer?

# %% [markdown]
# **Exercise 13:** Now define a pattern to answer the second question, and find the answer!
#
# Be careful, there is a little issue here:
# - Display the parse tree for the question and the matching document: what do you observe?
# - Build a pattern to match the question and the answer (Hint : you can use a list of dependency relations in the pattern, using e.g. *"RIGHT_ATTRS": {"DEP": {"IN":[ "acl", "advcl" ] }*
# - Finally, retrieve the answer

# %%
# Display the parse tree of the second question

# %%
# Display the parse tree of the matching document (first and unique sentence)

# %%
# Define a pattern that matches both the question and answer
# here we have a slight difference between the dep rel label for quest and answer
from spacy.matcher import DependencyMatcher
pattern_peinture = [
  #...

]

# %%
#  Apply the pattern to each sentence of this document, do you find the right answer?

# %% [markdown]
# **Exercise** Use the patterns defined to find the answers to the questions below. Here, we know that we're looking for the painter, we don'y want to match the question to the answer, we want to test known patterns to find the right answer.
#
# - find a way to extract the name of the painting from the question
# - retrieve the relevant document
# - test the patterns defined previously to extract the correct answer

# %%
new_questions = [
    'Qui a peint American Gothic ?',
    'Qui est l\'auteur de la peinture La Nuit étoilée',
    'Qui a réalisé Un Garrochista ?',
]

# %%
# Search entities in the question (there should be only one..)

# %%
# Retrive document

# %%
# Test the documents against several patterns

matcher = DependencyMatcher(nlp.vocab)
matcher.add("PAINTER", [pattern_tableau, pattern_peinture])

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# **Exercise** To go further
#
# Try to:
# - find who painted 'Le Cri' and 'Arearea
# - where are located 'La Joconde' and 'Arearea'
