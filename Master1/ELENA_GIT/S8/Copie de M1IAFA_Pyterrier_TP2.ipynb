# %% [markdown]
# # Université Paul Sabatier
#
# M1 IAFA - Recherche d'information
#
# **TP 2**
#
# Enseignant : José G. Moreno
#
# 2023

# %% [markdown]
# ## TP 2. Application de la RI pour la liaison référentielle

# %% [markdown]
# Une application des méthodes de RI est la liaison référentielle. Cette tâche consiste à trouver le lien entre une portion de texte et la page Wikipédia qui le représentent le mieux. Dans ce cas d’application :
# * Comme requêtes nous allons utiliser chaque mot dans une phrase (ou chaque mot important).
# * Le corpus sont les pages Wikipédia. Donc, chaque page Wikipédia est un document à retrouver.
# * La liste de résultats sont les candidats pour la liaison référentielle.
#
# Considère par exemple la chaîne de caractères « ***Thomas and Mario are strikers playing in Munich*** ». Il existe trois sous-chaînes (***Thomas***, ***Mario*** et ***Munich***) ou mots importants qui sont susceptibles d'être identifiées dans une base de connaissances telle que Wikipédia. Une recherche de ces mots-clés dans les pages Wikipédia produirait de nombreux concepts candidats pour ces sous-chaînes. Donc un bon système doit retrouver comme premier résultats les liens aux pages Wikipédia : [Thomas Müller](https://en.wikipedia.org/wiki/Thomas_M%C3%BCller), [Mario Gómez](https://en.wikipedia.org/wiki/Mario_G%C3%B3mez) (ou Mario Götze) et FC [Bayern Munich](https://en.wikipedia.org/wiki/FC_Bayern_Munich). Cette tâche est particulièrement complexe et les méthodes de recherche d’information sont particulièrement utiles pour la résoudre.

# %% [markdown]
# > Plusieurs méthodes de liaison référentielle (Entity Linking en anglais) sont disponibles sur internet. Les plus connus sont :
#
# >	* Spotlight → https://demo.dbpedia-spotlight.org/
# >	* Babelfy → http://babelfy.org/
# >	* TagMe → https://tagme.d4science.org/tagme/

# %% [markdown]
# ### 1) Liaison avec le texte
# En utilisant l’indexe du champ **text** de Wikipédia (comme dans le TP1) et la requête « Thomas and Mario are strikers playing in Munich » vérifiez si vous obtenez les pages Wikipédia respectives (comme le ferai Spotlight, Babelfy ou TagMe) :
# * Thomas Müller
# * Mario Gómez ou Mario Götze
# * FC Bayern Munich
#
# Voici un example:

# %%
# !wget "https://drive.google.com/uc?id=16rd8rFNR5qtjaX_vtZ__nqopq7Q6pSFu&confirm=t&uuid=0cc61c9f-387b-4218-b1e1-6421fb83d11e&at=ALgDtsx9J1qAF9DesqbqTEOfuLsR:1675797919874" -O pd_index.zip
# !unzip pd_index.zip
# Out:
# --2023-03-17 07:03:35--  https://drive.google.com/uc?id=16rd8rFNR5qtjaX_vtZ__nqopq7Q6pSFu&confirm=t&uuid=0cc61c9f-387b-4218-b1e1-6421fb83d11e&at=ALgDtsx9J1qAF9DesqbqTEOfuLsR:1675797919874
# Resolving drive.google.com (drive.google.com)... 173.194.217.101, 173.194.217.113, 173.194.217.100, ...
# Connecting to drive.google.com (drive.google.com)|173.194.217.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-9s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/te6as44sp78prs10qq67rjt5ma8o6d1u/1679036550000/12754483704616509995/*/16rd8rFNR5qtjaX_vtZ__nqopq7Q6pSFu?uuid=0cc61c9f-387b-4218-b1e1-6421fb83d11e [following]
# Warning: wildcards not supported in HTTP.
# --2023-03-17 07:03:35--  https://doc-14-9s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/te6as44sp78prs10qq67rjt5ma8o6d1u/1679036550000/12754483704616509995/*/16rd8rFNR5qtjaX_vtZ__nqopq7Q6pSFu?uuid=0cc61c9f-387b-4218-b1e1-6421fb83d11e
# Resolving doc-14-9s-docs.googleusercontent.com (doc-14-9s-docs.googleusercontent.com)... 172.253.123.132, 2607:f8b0:400c:c16::84
# Connecting to doc-14-9s-docs.googleusercontent.com (doc-14-9s-docs.googleusercontent.com)|172.253.123.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56607479 (54M) [application/zip]
# Saving to: ‘pd_index.zip’
#
# pd_index.zip        100%[===================>]  53.98M   161MB/s    in 0.3s
#
# 2023-03-17 07:03:36 (161 MB/s) - ‘pd_index.zip’ saved [56607479/56607479]
#
# Archive:  pd_index.zip
#    creating: pd_index/
#   inflating: pd_index/data.meta.idx
#   inflating: pd_index/data.inverted.bf
#   inflating: pd_index/data.lexicon.fsomaphash
#   inflating: pd_index/data.meta-0.fsomapfile
#   inflating: pd_index/data.lexicon.fsomapfile
#   inflating: pd_index/data.direct.bf
#   inflating: pd_index/data.lexicon.fsomapid
#   inflating: pd_index/data.properties
#   inflating: pd_index/data.meta.zdata
#   inflating: pd_index/data.document.fsarrayfile

# %%
# déclaration de la variable JAVA_HOME
import os
os.environ['JAVA_HOME'] = '/usr/lib/jvm/java-11-openjdk-amd64'
# !export JAVA_HOME=/usr/lib/jvm/java-11-openjdk-amd64

# %%
#installation de pyterrier avec pip
# !pip install --upgrade git+https://github.com/terrier-org/pyterrier.git#egg=python-terrier
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-terrier
#   Cloning https://github.com/terrier-org/pyterrier.git to /tmp/pip-install-fgrfanhq/python-terrier_d371cfc6a36f4d5982a415801f10a09a
#   Running command git clone --filter=blob:none --quiet https://github.com/terrier-org/pyterrier.git /tmp/pip-install-fgrfanhq/python-terrier_d371cfc6a36f4d5982a415801f10a09a
#   Resolved https://github.com/terrier-org/pyterrier.git to commit dc7997ed4bb4bbaf78f639a511bfe92fcd290c02
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.4.4)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from python-terrier) (4.65.0)
# Collecting pyjnius>=1.4.2
#   Downloading pyjnius-1.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 19.3 MB/s eta 0:00:00
# Collecting matchpy
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.2.2)
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting chest
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from python-terrier) (2.25.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from python-terrier) (1.1.1)
# Collecting nptyping==1.4.4
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.9/dist-packages (from python-terrier) (9.1.0)
# Collecting ir_datasets>=0.3.2
#   Downloading ir_datasets-0.5.4-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 KB 30.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from python-terrier) (3.1.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.9/dist-packages (from python-terrier) (0.13.5)
# Collecting ir_measures>=0.3.1
#   Downloading ir_measures-0.3.1.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 KB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 13.2 MB/s eta 0:00:00
# Collecting pytrec_eval_terrier>=0.5.3
#   Downloading pytrec_eval_terrier-0.5.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 KB 29.8 MB/s eta 0:00:00
# Collecting typish>=1.7.0
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 KB 5.0 MB/s eta 0:00:00
# Collecting zlib-state>=0.1.3
#   Downloading zlib_state-0.1.5-cp39-cp39-manylinux2010_x86_64.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 KB 7.0 MB/s eta 0:00:00
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting ijson>=3.1.3
#   Downloading ijson-3.2.0.post0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 KB 637.3 kB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.9.3)
# Collecting warc3-wet-clueweb09>=0.2.5
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lz4>=3.1.1
#   Downloading lz4-4.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.9/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.9.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from ir_datasets>=0.3.2->python-terrier) (6.0)
# Collecting pyautocorpus>=0.1.1
#   Downloading pyautocorpus-0.1.9-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 KB 28.3 MB/s eta 0:00:00
# Collecting unlzw3>=0.2.1
#   Downloading unlzw3-0.2.2-py3-none-any.whl (6.1 kB)
# Collecting cwl-eval>=1.0.10
#   Downloading cwl-eval-1.0.12.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from pyjnius>=1.4.2->python-terrier) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->python-terrier) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->python-terrier) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->python-terrier) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->python-terrier) (1.26.15)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.9/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated->python-terrier) (1.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->python-terrier) (2.1.2)
# Collecting multiset<3.0,>=2.0
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->python-terrier) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->python-terrier) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels->python-terrier) (23.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels->python-terrier) (0.5.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.4.1->ir_datasets>=0.3.2->python-terrier) (2.4)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python-terrier, ir_measures, chest, wget, cwl-eval, warc3-wet-clueweb09, cbor
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.9.2-py3-none-any.whl size=112519 sha256=456ae03affd6aa86f4b4af34cc19cb6e9176e1d3039951a599393c483521f4e5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t6tyf562/wheels/1b/7e/7c/19df81bd2538ca44417933eead7ee6f7c8a3044901e7fc46ee
#   Building wheel for ir_measures (setup.py) ... done
#   Created wheel for ir_measures: filename=ir_measures-0.3.1-py3-none-any.whl size=60184 sha256=0f82e65eb08caf5e40d82bfcfe20be43498e19de985cd1a28d5a3904246340bb
#   Stored in directory: /root/.cache/pip/wheels/00/fa/7d/0ba22fce7d11d69df68c31b7c247fbbb28fe2d4c610f8c653f
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7632 sha256=e6fef9457023c86df492922af90170e745d94386b989ff621d7fc7dace44a08b
#   Stored in directory: /root/.cache/pip/wheels/ce/05/8e/2ecd3728ed5d938ee57161c8acf2ee74f55f894964bb3d31ef
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=f0b548a998ee5adc78116e2e55da81b02fbf02291886f4e07f25a79385028689
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.12-py3-none-any.whl size=38083 sha256=8957be9fc80be7c59f34cd7cd15bed9a53c724c3bca4476051ef81aa4165d009
#   Stored in directory: /root/.cache/pip/wheels/0e/52/dc/9d448ff093ccae9b248a41b265d31e2c930eea2d0e84aa29e0
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18918 sha256=71818521c6234515191df76fe4f4276a87366f049d4da630b7288130bd040f4b
#   Stored in directory: /root/.cache/pip/wheels/7f/22/ed/a11944d7fdf4e94c4206a3f760d385122a4d34d8acc12f71a3
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp39-cp39-linux_x86_64.whl size=57294 sha256=ef5b95609a265de9fc2d80fe6db56e438f2c78a4aade9089f47f72913466694e
#   Stored in directory: /root/.cache/pip/wheels/ec/10/03/a281e0682ddd4b310431fb25d1a4f53987105267cf46c417f3
# Successfully built python-terrier ir_measures chest wget cwl-eval warc3-wet-clueweb09 cbor
# Installing collected packages: wget, warc3-wet-clueweb09, warc3-wet, typish, multiset, ijson, cbor, zlib-state, unlzw3, trec-car-tools, pytrec_eval_terrier, pyjnius, pyautocorpus, nptyping, matchpy, lz4, dill, deprecated, cwl-eval, chest, ir_measures, ir_datasets, python-terrier
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.12 deprecated-1.2.13 dill-0.3.6 ijson-3.2.0.post0 ir_datasets-0.5.4 ir_measures-0.3.1 lz4-4.3.2 matchpy-0.5.5 multiset-2.1.1 nptyping-1.4.4 pyautocorpus-0.1.9 pyjnius-1.4.2 python-terrier-0.9.2 pytrec_eval_terrier-0.5.5 trec-car-tools-2.6 typish-1.9.3 unlzw3-0.2.2 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.5

# %%
#Initialization de JVM
import pyterrier as pt
if not pt.started():
  pt.init()
# Out:
# terrier-assemblies 5.7 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.7 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7

# %%
indexref2 = pt.autoclass("org.terrier.querying.IndexRef").of(os.path.join("/content/pd_index", "data.properties"))

# %%
pt.BatchRetrieve(indexref2, wmodel="BM25", metadata=["docno","title","url"]).search("Thomas and Mario are strikers playing in Munich").head(50)
# Out:
#    qid   docid   docno                               title  \
# 0    1   28330  114620              Mario Strikers Charged
# 1    1   28329  114619                Mario Smash Football
# 2    1   71587  303588                       Audi Cup 2013
# 3    1   15782   60424                         Donkey Kong
# 4    1   13712   50727                      Princess Daisy
# 5    1  166504  771849                     Mario Balotelli
# 6    1    1074    4029                               Yoshi
# 7    1   13711   50725                      Princess Peach
# 8    1  113762  509811                       Audi Cup 2015
# 9    1   74872  321537                   Alexander Zickler
# 10   1  123459  575949                        Tobias Kempe
# 11   1    7608   24698                               Luigi
# 12   1   23374   89790                               Wario
# 13   1    1066    4016                               Mario
# 14   1   49028  176951                         David Villa
# 15   1   80432  349023                   201011 Bundesliga
# 16   1   80536  349533                   201112 Bundesliga
# 17   1  203375  901670                                 Phl
# 18   1  105314  458489                  Robert Lewandowski
# 19   1   93934  409469                    Charles Martinet
# 20   1   88436  383264                Mario Kart Arcade GP
# 21   1  113888  510362                 Stephan Beckenbauer
# 22   1   50168  181294                           Uli Hoene
# 23   1   96296  418172               Mario vs. Donkey Kong
# 24   1   88504  383601                  Mario Pinball Land
# 25   1  130855  617049                   Super Mario Maker
# 26   1   88355  382951             New Super Mario Bros. U
# 27   1  198725  885321                         Hohenlinden
# 28   1  186668  839449                Super Mario Bros. 35
# 29   1  201546  895457                      Luan Rodrigues
# 30   1   91475  399539                       Mario Party 8
# 31   1  186619  839196         Fortune Street (video game)
# 32   1  129217  607474                         Fritz Egner
# 33   1   90108  391634                       Mario Party 4
# 34   1    2720    8577                       Mario Party 6
# 35   1   60720  247372                        Thomas Mller
# 36   1   54533  206801                         Paper Mario
# 37   1   91476  399545                       Mario Party 7
# 38   1  171156  787634  Super Mario Bros. 35th Anniversary
# 39   1   59794  242678                         Super Mario
# 40   1  182274  824105               Mario Slam Basketball
# 41   1   27553  111365           Mario Kart: Super Circuit
# 42   1  197370  879835                        Bernd Nickel
# 43   1   73386  314467                       SVG Reichenau
# 44   1   68999  293186                     Gerhard Tremmel
# 45   1   52656  195267                          Gary Twigg
# 46   1   55514  213649                       Marcel Schfer
# 47   1   88604  384261                       Mario Party 3
# 48   1   98469  429590                        Dr. Mario 64
# 49   1   98136  428138                          Bowser Jr.
#
#                                                   url  rank      score  \
# 0   https://simple.wikipedia.org/wiki/Mario%20Stri...     0  30.771667
# 1   https://simple.wikipedia.org/wiki/Mario%20Smas...     1  30.306808
# 2   https://simple.wikipedia.org/wiki/Audi%20Cup%2...     2  29.796582
# 3     https://simple.wikipedia.org/wiki/Donkey%20Kong     3  28.570535
# 4   https://simple.wikipedia.org/wiki/Princess%20D...     4  28.192863
# 5   https://simple.wikipedia.org/wiki/Mario%20Balo...     5  27.400834
# 6             https://simple.wikipedia.org/wiki/Yoshi     6  25.804927
# 7   https://simple.wikipedia.org/wiki/Princess%20P...     7  25.073465
# 8   https://simple.wikipedia.org/wiki/Audi%20Cup%2...     8  24.388908
# 9   https://simple.wikipedia.org/wiki/Alexander%20...     9  23.780821
# 10   https://simple.wikipedia.org/wiki/Tobias%20Kempe    10  23.603799
# 11            https://simple.wikipedia.org/wiki/Luigi    11  22.692159
# 12            https://simple.wikipedia.org/wiki/Wario    12  21.020281
# 13            https://simple.wikipedia.org/wiki/Mario    13  20.935477
# 14    https://simple.wikipedia.org/wiki/David%20Villa    14  20.862224
# 15  https://simple.wikipedia.org/wiki/2010%E2%80%9...    15  20.755765
# 16  https://simple.wikipedia.org/wiki/2011%E2%80%9...    16  20.655217
# 17        https://simple.wikipedia.org/wiki/P%C3%A4hl    17  20.533782
# 18  https://simple.wikipedia.org/wiki/Robert%20Lew...    18  20.356859
# 19  https://simple.wikipedia.org/wiki/Charles%20Ma...    19  19.695213
# 20  https://simple.wikipedia.org/wiki/Mario%20Kart...    20  19.566381
# 21  https://simple.wikipedia.org/wiki/Stephan%20Be...    21  19.550553
# 22  https://simple.wikipedia.org/wiki/Uli%20Hoene%...    22  19.543601
# 23  https://simple.wikipedia.org/wiki/Mario%20vs.%...    23  19.542285
# 24  https://simple.wikipedia.org/wiki/Mario%20Pinb...    24  19.319084
# 25  https://simple.wikipedia.org/wiki/Super%20Mari...    25  19.296400
# 26  https://simple.wikipedia.org/wiki/New%20Super%...    26  19.263808
# 27      https://simple.wikipedia.org/wiki/Hohenlinden    27  19.197015
# 28  https://simple.wikipedia.org/wiki/Super%20Mari...    28  19.140112
# 29  https://simple.wikipedia.org/wiki/Luan%20Rodri...    29  19.071240
# 30  https://simple.wikipedia.org/wiki/Mario%20Part...    30  19.038564
# 31  https://simple.wikipedia.org/wiki/Fortune%20St...    31  18.971374
# 32    https://simple.wikipedia.org/wiki/Fritz%20Egner    32  18.924370
# 33  https://simple.wikipedia.org/wiki/Mario%20Part...    33  18.877112
# 34  https://simple.wikipedia.org/wiki/Mario%20Part...    34  18.831535
# 35  https://simple.wikipedia.org/wiki/Thomas%20M%C...    35  18.725876
# 36    https://simple.wikipedia.org/wiki/Paper%20Mario    36  18.695550
# 37  https://simple.wikipedia.org/wiki/Mario%20Part...    37  18.679694
# 38  https://simple.wikipedia.org/wiki/Super%20Mari...    38  18.664973
# 39    https://simple.wikipedia.org/wiki/Super%20Mario    39  18.554873
# 40  https://simple.wikipedia.org/wiki/Mario%20Slam...    40  18.548969
# 41  https://simple.wikipedia.org/wiki/Mario%20Kart...    41  18.482298
# 42   https://simple.wikipedia.org/wiki/Bernd%20Nickel    42  18.480602
# 43  https://simple.wikipedia.org/wiki/SVG%20Reichenau    43  18.478638
# 44  https://simple.wikipedia.org/wiki/Gerhard%20Tr...    44  18.477631
# 45     https://simple.wikipedia.org/wiki/Gary%20Twigg    45  18.390747
# 46  https://simple.wikipedia.org/wiki/Marcel%20Sch...    46  18.332757
# 47  https://simple.wikipedia.org/wiki/Mario%20Part...    47  18.321284
# 48  https://simple.wikipedia.org/wiki/Dr.%20Mario%...    48  18.281506
# 49     https://simple.wikipedia.org/wiki/Bowser%20Jr.    49  18.236685
#
#                                               query
# 0   Thomas and Mario are strikers playing in Munich
# 1   Thomas and Mario are strikers playing in Munich
# 2   Thomas and Mario are strikers playing in Munich
# 3   Thomas and Mario are strikers playing in Munich
# 4   Thomas and Mario are strikers playing in Munich
# 5   Thomas and Mario are strikers playing in Munich
# 6   Thomas and Mario are strikers playing in Munich
# 7   Thomas and Mario are strikers playing in Munich
# 8   Thomas and Mario are strikers playing in Munich
# 9   Thomas and Mario are strikers playing in Munich
# 10  Thomas and Mario are strikers playing in Munich
# 11  Thomas and Mario are strikers playing in Munich
# 12  Thomas and Mario are strikers playing in Munich
# 13  Thomas and Mario are strikers playing in Munich
# 14  Thomas and Mario are strikers playing in Munich
# 15  Thomas and Mario are strikers playing in Munich
# 16  Thomas and Mario are strikers playing in Munich
# 17  Thomas and Mario are strikers playing in Munich
# 18  Thomas and Mario are strikers playing in Munich
# 19  Thomas and Mario are strikers playing in Munich
# 20  Thomas and Mario are strikers playing in Munich
# 21  Thomas and Mario are strikers playing in Munich
# 22  Thomas and Mario are strikers playing in Munich
# 23  Thomas and Mario are strikers playing in Munich
# 24  Thomas and Mario are strikers playing in Munich
# 25  Thomas and Mario are strikers playing in Munich
# 26  Thomas and Mario are strikers playing in Munich
# 27  Thomas and Mario are strikers playing in Munich
# 28  Thomas and Mario are strikers playing in Munich
# 29  Thomas and Mario are strikers playing in Munich
# 30  Thomas and Mario are strikers playing in Munich
# 31  Thomas and Mario are strikers playing in Munich
# 32  Thomas and Mario are strikers playing in Munich
# 33  Thomas and Mario are strikers playing in Munich
# 34  Thomas and Mario are strikers playing in Munich
# 35  Thomas and Mario are strikers playing in Munich
# 36  Thomas and Mario are strikers playing in Munich
# 37  Thomas and Mario are strikers playing in Munich
# 38  Thomas and Mario are strikers playing in Munich
# 39  Thomas and Mario are strikers playing in Munich
# 40  Thomas and Mario are strikers playing in Munich
# 41  Thomas and Mario are strikers playing in Munich
# 42  Thomas and Mario are strikers playing in Munich
# 43  Thomas and Mario are strikers playing in Munich
# 44  Thomas and Mario are strikers playing in Munich
# 45  Thomas and Mario are strikers playing in Munich
# 46  Thomas and Mario are strikers playing in Munich
# 47  Thomas and Mario are strikers playing in Munich
# 48  Thomas and Mario are strikers playing in Munich
# 49  Thomas and Mario are strikers playing in Munich

# %% [markdown]
# ### 2) Les poids
#
# Utilisez les différents méthodes de pondération prédefinies sur pyterrier (http://terrier.org/docs/v5.2/javadoc/org/terrier/matching/models/package-summary.html) pour voir s’il existent des méthodes que vous donnent de meilleurs résultats, c’est-à-dire inspectez les 10 premiers résultats et vérifiez si les pages d’intérêt (Thomas Müller, Mario Gómez ou Mario Götze et FC Bayern Munich) font partie des résultats, puis les 20 premiers, et finalement les 50 premiers. Existent-ils de différences importantes ?

# %%
data = pt.BatchRetrieve(indexref2, wmodel="DFRee", metadata=["docno","title","url"]).search("Thomas and Mario are strikers playing in Munich").head(50)
data.loc[(data['title'] == 'Thomas Mller') | (data['title'] == 'Mario Gmez')]
# Out:
#    qid  docid   docno         title  \
# 22   1  60720  247372  Thomas Mller
# 26   1  23770   91696    Mario Gmez
#
#                                                   url  rank      score  \
# 22  https://simple.wikipedia.org/wiki/Thomas%20M%C...    22  23.242646
# 26  https://simple.wikipedia.org/wiki/Mario%20G%C3...    26  22.415637
#
#                                               query
# 22  Thomas and Mario are strikers playing in Munich
# 26  Thomas and Mario are strikers playing in Munich

# %%
data = pt.BatchRetrieve(indexref2, wmodel="LGD", metadata=["docno","title","url"]).search("Thomas and Mario are strikers playing in Munich").head(50)
data.loc[(data['title'] == 'Thomas Mller') | (data['title'] == 'Mario Gmez')]
# Out:
#    qid  docid   docno         title  \
# 22   1  23770   91696    Mario Gmez
# 25   1  60720  247372  Thomas Mller
#
#                                                   url  rank      score  \
# 22  https://simple.wikipedia.org/wiki/Mario%20G%C3...    22  19.105551
# 25  https://simple.wikipedia.org/wiki/Thomas%20M%C...    25  18.311461
#
#                                               query
# 22  Thomas and Mario are strikers playing in Munich
# 25  Thomas and Mario are strikers playing in Munich

# %% [markdown]
# ### 3) Utilisation de termes
# Une stratégie consiste à utiliser individuellement chaque terme de la requête pour voir si vous arrivez à trouver les pages d’intérêt. Un code exemple est donné ci-dessous, cependant il n'est pas suffisant pour faire la tâche. Une fois fini votre code, réalisez la même vérification de résultats que dans le point précédent.

# %%
query = "Thomas and Mario are strikers playing in Munich"
termToSearch = [x for x in query.split() if x[0]==x[0].upper()]
print(termToSearch)
for term, page in zip(termToSearch,['Thomas Mller','Mario Gtze', 'FC Bayern Munich']):
  dfres = pt.BatchRetrieve(indexref2, wmodel="BM25", metadata=["docno","title","url"]).search(term)[['title','score']]
  print(dfres.head(10))
  print("Position de la page attendue dans les résultats :\n",dfres[dfres['title']==page],"\n\n\n")
# Out:
# ['Thomas', 'Mario', 'Munich']
#                          title      score
# 0             Thomas (surname)  11.700841
# 1                 Saint Thomas  11.597729
# 2           Thomas the Apostle  11.447421
# 3                Thomas County  11.387148
# 4           Thomas Wedgwood IV  11.210921
# 5                 Sarah Thomas  11.152142
# 6                 Helen Thomas  11.145990
# 7             Gospel of Thomas  11.121265
# 8      Thomas White (merchant)  11.026214
# 9  Mallappally Marthoma Church  11.013052
# Position de la page attendue dans les résultats :
#  Empty DataFrame
# Columns: [title, score]
# Index: []
#
#
#
#                           title      score
# 0                Princess Peach  16.478378
# 1        Mario (disambiguation)  16.451796
# 2  Super Mario (disambiguation)  16.419316
# 3                         Mario  16.395732
# 4              Charles Martinet  16.349001
# 5                    Bowser Jr.  16.214048
# 6                         Wario  16.177717
# 7                         Luigi  16.132403
# 8                   Mario Bros.  15.990315
# 9                Princess Daisy  15.961688
# Position de la page attendue dans les résultats :
#            title     score
# 444  Mario Gtze  6.193161
#
#
#
#                          title      score
# 0                   Bundesliga  15.502280
# 1      Olympiastadion (Munich)  15.192906
# 2                       Munich  15.082408
# 3                Audi Cup 2015  14.993887
# 4  Technical University Munich  14.951113
# 5                    Munich RE  14.887408
# 6          Stephan Beckenbauer  14.885528
# 7               Altstadt-Lehel  14.833179
# 8         University of Munich  14.782431
# 9                         Laim  14.782431
# Position de la page attendue dans les résultats :
#                  title      score
# 177  FC Bayern Munich  11.500917

# %% [markdown]
# ### 4) Le titre
# Maintenant utilisez le champ ***title*** avec la requête complète et avec chaque terme. Expliquez  pourquoi les résultats sont différents.

# %%
# !unzip pd_index2.zip
# Out:
# Archive:  pd_index2.zip
#    creating: pd_index2/
#   inflating: pd_index2/data.properties
#   inflating: pd_index2/data.lexicon.fsomapfile
#   inflating: pd_index2/data.direct.bf
#   inflating: pd_index2/data.inverted.bf
#   inflating: pd_index2/data.meta.idx
#   inflating: pd_index2/data.lexicon.fsomaphash
#   inflating: pd_index2/data.meta-0.fsomapfile
#   inflating: pd_index2/data.document.fsarrayfile
#   inflating: pd_index2/data.lexicon.fsomapid
#   inflating: pd_index2/data.meta.zdata

# %%
indexref4 = pt.autoclass("org.terrier.querying.IndexRef").of(os.path.join("/content/pd_index2", "data.properties"))
data = pt.BatchRetrieve(indexref4, wmodel="DFRee", metadata=["docno","title","url"]).search("Thomas and Mario are strikers playing in Munich").head(50)
data.loc[(data['title'] == 'Thomas Mller') | (data['title'] == 'Mario Gmez')]
# Out:
# Empty DataFrame
# Columns: [qid, docid, docno, title, url, rank, score, query]
# Index: []

# %%
data = pt.BatchRetrieve(indexref4, wmodel="LGD", metadata=["docno","title","url"]).search("Thomas and Mario are strikers playing in Munich").head(50)
data.loc[(data['title'] == 'Thomas Mller') | (data['title'] == 'Mario Gmez')]
# Out:
# Empty DataFrame
# Columns: [qid, docid, docno, title, url, rank, score, query]
# Index: []

# %% [markdown]
# ### 5) L'outil
# Développez un outil/méthode/système capable de recevoir comme entrée un paragraphe de texte et comme sortie une liste ordonné de pages Wikipédia pour chaque unité lexical (token ou mot) dans le paragraphe.

# %%
def systeme(paragraph, model,index) :
  res = []
  mots = paragraph.split()
  mots_majuscules = [mot for mot in mots if mot[0].isupper()]
  
  for mot in mots_majuscules:
    res.append(pt.BatchRetrieve(index, wmodel=model, metadata=["docno","title","url"]).search(mot).head(10))
  
  print(res)

# %%
text = "Thomas and Mario are strikers playing in Munich"
systeme(text,"BM25",indexref4)
# Out:
# [  qid   docid   docno                  title  \
# 0   1    3543   10625           B. J. Thomas
# 1   1   16140   61986            Thomas More
# 2   1  107452  466857  Thomas Thomas (boxer)
# 3   1    1804    6070          Thomas Hobbes
# 4   1    2264    7509       Thomas Jefferson
# 5   1    2425    7796           Thomas Dolby
# 6   1    3984   12320           Dylan Thomas
# 7   1    4160   12950          Thomas Edison
# 8   1    6093   19552        Clarence Thomas
# 9   1    8167   27207     Thomas the Apostle
#
#                                                  url  rank      score   query
# 0  https://simple.wikipedia.org/wiki/B.%20J.%20Th...     0  11.861736  Thomas
# 1    https://simple.wikipedia.org/wiki/Thomas%20More     1  11.861736  Thomas
# 2  https://simple.wikipedia.org/wiki/Thomas%20Tho...     2  11.491433  Thomas
# 3  https://simple.wikipedia.org/wiki/Thomas%20Hobbes     3   9.566962  Thomas
# 4  https://simple.wikipedia.org/wiki/Thomas%20Jef...     4   9.566962  Thomas
# 5   https://simple.wikipedia.org/wiki/Thomas%20Dolby     5   9.566962  Thomas
# 6   https://simple.wikipedia.org/wiki/Dylan%20Thomas     6   9.566962  Thomas
# 7  https://simple.wikipedia.org/wiki/Thomas%20Edison     7   9.566962  Thomas
# 8  https://simple.wikipedia.org/wiki/Clarence%20T...     8   9.566962  Thomas
# 9  https://simple.wikipedia.org/wiki/Thomas%20the...     9   9.566962  Thomas  ,   qid  docid   docno                   title  \
# 0   1   1066    4016                   Mario
# 1   1  52921  196812                 Z Mario
# 2   1   2054    6805            Mario Jeckle
# 3   1   7554   24377             Mario Bros.
# 4   1  20268   77849  Mario (disambiguation)
# 5   1  23770   91696              Mario Gmez
# 6   1  25369   99951          Mario Capecchi
# 7   1  25945  102445              Mario Kart
# 8   1  28417  115089          Mario (series)
# 9   1  44719  157983            Mario Kempes
#
#                                                  url  rank      score  query
# 0            https://simple.wikipedia.org/wiki/Mario     0  13.130843  Mario
# 1  https://simple.wikipedia.org/wiki/Z%C3%A9%20Mario     1  13.130843  Mario
# 2   https://simple.wikipedia.org/wiki/Mario%20Jeckle     2  10.590548  Mario
# 3    https://simple.wikipedia.org/wiki/Mario%20Bros.     3  10.590548  Mario
# 4  https://simple.wikipedia.org/wiki/Mario%20%28d...     4  10.590548  Mario
# 5  https://simple.wikipedia.org/wiki/Mario%20G%C3...     5  10.590548  Mario
# 6  https://simple.wikipedia.org/wiki/Mario%20Cape...     6  10.590548  Mario
# 7     https://simple.wikipedia.org/wiki/Mario%20Kart     7  10.590548  Mario
# 8  https://simple.wikipedia.org/wiki/Mario%20%28s...     8  10.590548  Mario
# 9   https://simple.wikipedia.org/wiki/Mario%20Kempes     9  10.590548  Mario  ,   qid   docid   docno                 title  \
# 0   1     576    2917                Munich
# 1   1  131199  619731             Munich RE
# 2   1   11138   40178         Munich U-Bahn
# 3   1   11178   40456        Munich Airport
# 4   1   25774  101729     Munich (district)
# 5   1   28411  115068      Munich Agreement
# 6   1  100868  440744       Munich massacre
# 7   1  155873  743468  University of Munich
# 8   1  184224  831013        Bavaria-Munich
# 9   1  184495  832080    Boroughs of Munich
#
#                                                  url  rank      score   query
# 0           https://simple.wikipedia.org/wiki/Munich     0  16.842390  Munich
# 1      https://simple.wikipedia.org/wiki/Munich%20RE     1  16.842390  Munich
# 2  https://simple.wikipedia.org/wiki/Munich%20U-Bahn     2  13.584058  Munich
# 3  https://simple.wikipedia.org/wiki/Munich%20Air...     3  13.584058  Munich
# 4  https://simple.wikipedia.org/wiki/Munich%20%28...     4  13.584058  Munich
# 5  https://simple.wikipedia.org/wiki/Munich%20Agr...     5  13.584058  Munich
# 6  https://simple.wikipedia.org/wiki/Munich%20mas...     6  13.584058  Munich
# 7  https://simple.wikipedia.org/wiki/University%2...     7  13.584058  Munich
# 8   https://simple.wikipedia.org/wiki/Bavaria-Munich     8  13.584058  Munich
# 9  https://simple.wikipedia.org/wiki/Boroughs%20o...     9  13.584058  Munich  ]

# %% [markdown]
# ---
#
#
#
# En plus à l’information du TP, vous pouvez utiliser les ressources/idées suivants pour améliorer les résultats du système à développer :
# - La combinaison de plusieurs méthodes de pondération c’est possible en utilisant les indications sur https://pyterrier.readthedocs.io/en/latest/pipeline_examples.html .
# - Comme mentionné dans le TP1, il existe plusieurs type de champs. On a utilisé celui de la classe TextField. Renseignez vous sur les autres (StringField par exemple) et ses différences.
# - Les distances d’édition sont largement utilisés par les moteurs de recherche. Par exemple si vous tapez « paris sain germain » sur Google il va vous suggérer la requête « paris saint germain » l’équipe de football. Vous pouvez utiliser les distances d’édition pour trouver des entités avec une orthographe différent que celle sur Wikipédia. Une de distance très performantes est la distance Levenshtein implémentée dans la classe LuceneLevenshteinDistance du paquet lucene.search.spell.
# - Les moteurs de recherche peuvent être utilisés pour calculer la similarité entre les mots ou entre les entités. Par exemple, sur Google si vous tapez « orange » et « carrot » il y a plus de résultats que si vous tapez « purple » et « carrot ». Vous pouvez utiliser cette information pour décider si deux pages Wikipédia font partie d’un même sujet.
# - Utilisez le fichier [anchor_text_en.ttl](http://downloads.dbpedia.org/2015-10/core-i18n/en/anchor_text_en.ttl.bz2) qui contient les anchor texts  de la Wikipédia en anglais. Le format du fichier est décrit [ici](https://iai-group.github.io/DBpedia-Entity/index_details.html). Transformez-le dans ce format au autre similaire pour faire l'indexation:
#
# |             Frequency                 	|       Wikipedia Page        	| Anchor Text 	|
# |------------------------------	|---------------	|-----------	|
# |162| \<Saturn_Award_for_Best_Supporting_Actor> |"Best Supporting Actor"|
# |14 |\<André_Golke>| "Golke"|
# |13 |\<Charles_Pinckney_National_Historic_Site> |"Charles Pinckney National Historic Site"|
# |25 |\<Thomas_Manfredini>| "Manfredini"|
# |13 |<Marek_Zieńczuk> |"Marek Zieńczuk"|
# |14 |\<Sigurd_Ulveseth>| "Sigurd Ulveseth"|
# |104| <Pole_Position_(video_game)>| "Pole Position"|
# |10| <Bang_(band)>| "Bang"|
# |44| <George_Susce_(catcher)>| "George Susce"|
# |11| \<Kyle_Rankin>| "Kyle Rankin"|
# |…|…|…|
#
# Donc, la premier colonne correspond au nombre de fois que la chaîne de caractères de la troisième colonne a été utilisé pour faire allusion à la page Wikipédia de la deuxième colonne. C’est-à-dire que "Best Supporting Actor" a été utilisé 162 fois dans Wikipédia pour faire allusion à la page Wikipédia https://en.wikipedia.org/wiki/Saturn_Award_for_Best_Supporting_Actor . Le fichier anchor_text_en.tll  contient les informations de la Wikipédia en anglais et pas de la Wikipédia simple, donc certain titres n’ont pas de correspondance.
